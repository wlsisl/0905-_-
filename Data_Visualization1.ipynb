# %% [markdown]
# <a href="https://colab.research.google.com/github/wlsisl/ESAA_22-2/blob/main/Data_Visualization1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **04-1 데이터 시각화가 필요한 이유**
#
# ### **(1) 앤스콤 4분할 그래프 살펴보기**
# 앤스콤 4분할 그래프(Anscombe's quartet) : 데이터를 시각화하지 않고 수치만 확인할 때 발생할 수 있는 함정을 보여주기 위해 만든 그래프
#
# - 앤스콤이 지적한 함정과 데이터 시각화의 필요성
#
#  4분할 그래프를 구성하는 데이터 집합은 4개의 그룹으로 구성되어 있는데 모든 그룹은 **평균, 분산과 같은 수칫값이나 상관관계, 회귀선**이 같다는 특징이 있다. 그래서 **'데이터 4그룹이 모두 같을 것이다'**라고 착각할 수 있다. 하지만 각 데이터 그룹을 시각화하면 데이터 그룹이 서로 다른 데이터 패턴을 가지고 있다.
#
#
#
# ### **`  <앤스콤 데이터 집합 불러온 후 그래프 그리기>`**
#
# 1. 앤스콤 데이터 집합 불러오기
#  * 위 집합은 seaborn 라이브러리에 포함
#  * 위 라이브러리의 load_dataset 메서드에 문자열 anscombe을 전달 -> 앤스콤 데이터 집합 불러옴
#  * 이때 dataset열이 데이터 그룹을 구분해줌

# %%
import numpy as np
import pandas as pd
import seaborn as sns

anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# 2. matplotlib라이브러리로 그래프 그리기

# %%
#라이브러리 불러오기
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# 3. dataset열에서 데이터 값이 I인 것만 추출한 것. 즉 첫번재 데이터 그룹 추출하기

# %%
dataset_1=anscombe[anscombe['dataset']=='I']

# %% [markdown]
# 4. plot메서드로 선그래프 그리기

# %%
plt.plot(dataset_1['x'],dataset_1['y'])

# %% [markdown]
# 5. 점으로 그래프를 그려보자
#  * plot 메서드는 기본적으로 선으로 그래프를 그려준다.

# %%
plt.plot(dataset_1['x'],dataset_1['y'],'o')

# %% [markdown]
# ### **(2) 앤스콤 데이터 집합 모두 사용해 그래프 만들기**
#  * matplotlib 라이브러리로 그래프 그리기
#    #### **<과정>**
#
#     1) 전체 그래프가 위치할 기본 틀을 만든다.
#
#     2) 그래프를 그려 넣을 그래프 격자를 만든다.
#
#     3) 그런 다음 격자에 그래프를 하나씩 추가한다. 격자에 그래프가 추가되는 순서는 왼쪽에서 오른쪽 방향이다.
#
#     4) 만약 격자의 첫 번째 행이 꽉 차면 두 번째 행에 그래프를 그려 넣는다.
#
# ### **`<한 번에 4개의 그래프 그리기>`**
#
# 1) 앤스콤 데이터 프레임의 dataset열의 값이 I,II,III,IV 인 것을 불린 추출하여 저장하기.

# %%
dataset_2= anscombe[anscombe['dataset']=='II']
dataset_3= anscombe[anscombe['dataset']=='III']
dataset_4= anscombe[anscombe['dataset']=='IV']

# %% [markdown]
# 2) 그래프 격자가 위치할 기본 틀 만들기

# %%
fig=plt.figure()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <div id='0fdc069c-eea5-4bae-a8dd-410f747b88c3'></div>

# %% [markdown]
# 3. add_subplot 메서드로 그래프 격자그리기
#   * 기본 틀(fig)에 격자를 추가하는 방식
#   * 첫 번째 인자 :그래프 기본 틀의 행 크기
#
#     두 번째 인자 : 그래프 기본 틀의 열 크기

# %%
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %% [markdown]
# 4) plot메서드에 데이터를 전달하여 그래프 그리기

# %%
axes1.plot(dataset_1['x'], dataset_1['y'],'o')
axes2.plot(dataset_2['x'], dataset_2['y'],'o')
axes3.plot(dataset_3['x'], dataset_3['y'],'o')
axes4.plot(dataset_4['x'], dataset_4['y'],'o')

# %% [markdown]
# 5) 그래프 격자에 제목 추가하기
#  * set_title메서드 사용

# %%
axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")
# Out:
# Text(0.5, 1.0, 'dataset_4')

# %% [markdown]
# 6) 기본 틀(fig)에도 제목 추가하기
#  * suptitle 메서드 사용

# %%
fig.suptitle("Anscombe Data")
fig
# Out:
# <div id='6e160708-f2a4-44a2-b15f-2d94ebfc3e54'></div>

# %% [markdown]
# 7) 5,6번에서 그래프의 이름과 숫자가 겹쳐보인다. 각 그래프 레이아웃 조절하기
# * tight_layout 메서드 이용

# %%
fig.tight_layout()
fig
# Out:
# <div id='e2dad85f-5ac8-4f5c-afb4-22675218a925'></div>

# %% [markdown]
# ## **04-2 matplotlib 라이브러리 자유자재로 사용하기**
#
# ### (1) 기초 그래프 그리기
#  * seaborn 라이브러리에는 tips라는 데이터 집합이 있다.
#
#  ### **`<기초 그래프 그리기 - 히스토그램, 산점도 그래프, 박스 그래프>`**
#
# 1) tips 데이터 집합을 불러와 변수 tips에 저장

# %%
tips = sns.load_dataset("tips")
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 2) 히스토그램 그래프 : 데이터프레임의 열 데이터 분포와 빈도를 살펴보는 용도
#
#   일변량 그래프 : 변수를 하나만 사용해서 그린 그래프
#
# 3) 기본틀을 마련하고 격자를 구성하자

# %%
fig=plt.figure()
axes1=fig.add_subplot(1,1,1)
# Out:
# <div id='e3986c0b-bee7-45a6-beff-c04949ba33f9'></div>

# %% [markdown]
# 4) 히스토그램 만들기
#  * hist 메서드에 total_bill 열 전달하기
#  * bins 인잣값으로 x축의 간격 조절

# %%
axes1.hist(tips['total_bill'],bins=10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

fig
# Out:
# <div id='c26e719b-0a26-484e-a393-d7a5323bb7b9'></div>

# %% [markdown]
# 5) 산점도 그리기
#  * 변수 2개를 사용한다.
#  * 이변량 그래프라고 부른다.
#
# 6) 기본틀과 격자를 만들고 scatter 메서드에 두 열을 전달한다.

# %%
#total_bill열에 따른 tip열의 분포를 나타낸 산점도 그래프
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <div id='34e98583-f8b8-412e-a23b-571b2611e488'></div>
# Text(0, 0.5, 'Tip')

# %% [markdown]
# 7) 박스 그래프 그리기
#  * 이산형 변수와 연속형 변수를 함께 사용함
#  * boxplot 메서드를 사용한다.
#
# 8) boxplot 메서드 사용

# %%
boxplot = plt.figure()
axes1= boxplot.add_subplot(1,1,1)
axes1.boxplot([tips[tips['sex']=='Female']['tip'], tips[tips['sex']=='Male']['tip']], labels=['Female','Male'])
axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# <div id='7e9a2d3c-4c5b-4437-b6af-7716ad799b8e'></div>
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# ### (2) 다변량 그래프 그리기
#  * 3개 이상의 변수를 사용한 그래프
#
# > 다변량 그래프가 필요한 이유 ?
#
# 앞에서는 지불금액과 팁만을 사용하여 산점도를 그렸는데 만약 여기에 성별을 추가하여 산점도를 표현하려면? **점의 색상을 다르게** 한다.
# 즉 점의 크기를 다르게 하던지 해서 구분 방식을 다양하게 추가한다.
#
#  ### **`<다변량 데이터로 다변량 그래프 그리기 - 산점도 그래프>`**
#
#  1) 앞의 scatter_plot 산점도 그래프에 성별을 새 변수로 추가하여 색상으로 구분하기
#   * 문자열은 산점도 그래프의 색상을 지정하는 값으로 사용할 수 없다. 즉 문자열을 정수로 치환하는 함수를 만들어야한다.

# %%
def recode_sex(sex):
  if sex=='Female':
    return 0
  else:
    return 1

# %% [markdown]
# 2) recode_sex 메서드가 반환한 값을 데이터 프레임에 추가한다.

# %%
tips['sex_color']= tips['sex'].apply(recode_sex)

# %% [markdown]
# 3) 테이블당 인원 수는 점의 크기로 표현하여 그래프에 추가하기

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips['total_bill'], y=tips['tip'],s=tips['size']*10, c=tips['sex_color'], alpha = 0.5) #alpha 인자값 : 점의 투명도 조절
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
# Out:
# <div id='eab69d7a-31f8-4c80-b83b-85c6f907d9a0'></div>
# Text(0.5, 1.0, 'Total Bill vs Tip Colored by Sex and Sized by Size')

# %% [markdown]
# ## **04-3 seaborn 라이브러리 자유자재로 사용하기**
#
# 앞에서는 seaborn 라이브러리의 tips 데이터 집합만 사용하였지만 이번에는 이 라이브러리 자체를 활용하자. 좀 더 화려한 그래프를 그릴 수 있다.
#
#  ### **`<단변량 그래프 그리기 - 히스토그램>`**
#
#  1) seaborn 라이브러리를 sns라는 이름으로 줄여 사용한다.

# %%
import seaborn as sns
tips=sns.load_dataset("tips") #tips데이터 집합을 불러온다.

# %% [markdown]
# 2) seaborn 라이브러리로 히스토그램을 그리는 방법
#   * subplots 메서드 : 기본 틀을 만든다.
#   * displot 메서드 : total_bill 열 데이터를 전달

# %%
ax = plt.subplots()
ax=sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# <div id='28b1f5b2-a983-4d0e-b5bc-c902b8de356f'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %% [markdown]
# 3) 밀집도 그래프가 디폴트로 제공되는데 제외하고 싶다면 kde=False

# %%
ax = plt.subplots()
ax=sns.distplot(tips['total_bill'],kde=False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <div id='e611f95a-9614-46a9-bb36-3ae683880574'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# 4) 밀집도만 나타내려면 hist=False

# %%
ax = plt.subplots()
ax=sns.distplot(tips['total_bill'],hist=False)
ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')
# Out:
# <div id='b2b87510-ebc8-4fa6-aff0-403f20402a0c'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Unit Probability')

# %% [markdown]
# 5) 히스토그램과 밀집도를 그리는 distplot 메서드에 rug인자를 추가하여 양탄자 (rug)그래프까지 그린다.
#  * rug 그래프 : 그래프의 축에 동일한 길이의 직선을 붙여 데이터의 밀접 정도를 표현한 그래프

# %%
ax = plt.subplots()
ax=sns.distplot(tips['total_bill'],rug=True)
ax.set_title('Total Bill Histogram with Density Plot')
ax.set_xlabel('Total Bill')
# Out:
# <div id='0149b892-f179-48b9-b1d0-60dba6431ed4'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Total Bill')

# %% [markdown]
# 6) count 그래프 그리기 - 이산값을 나타낸 그래프

# %%
ax = plt.subplots()
ax=sns.countplot('day',data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# <div id='24992cde-c12d-4d67-a1ef-2edfe920be91'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Frequency')

# %% [markdown]
#  ### **`<다양한 종류의 이변량 그래프 그리기>`**
#
#  1) seaborn 라이브러리로 산점도 그래프 그리기
#   * regplot 메서드 : 산점도 그래프와 회귀선을 함께 그린다. 이때 **fit_reg=False 하면 회귀선 제거**해줌

# %%
ax = plt.subplots()
ax=sns.regplot(x='total_bill', y='tip',data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <div id='0b354056-6f07-41fa-b89a-73bf595babee'></div>
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
ax=sns.regplot(x='total_bill', y='tip',data=tips, fit_reg = False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <div id='7dfb991b-5404-4633-8314-d6b0060a21c7'></div>
# Text(0, 0.5, 'Tip')

# %% [markdown]
# 2)  jointplot 메서드 : 산점도와 히스토그램을 한번에 그려줌

# %%
joint = sns.jointplot(x='total_bill',y='tip', data=tips)
joint.set_axis_labels(xlabel='Total Bill',ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# <div id='adabe417-e1b9-4cb0-820a-75a2ff7c1e2c'></div>
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %% [markdown]
# 3) 육각 그래프
#  * 2차원 표면에 육각형으로 데이터를 쌓아 표현한다.
#  * 그래프의 데이터를 구분하기 쉽다.
#  * 특정 데이터의 개수가 많아지면 점점 진한 색으로 표현함
#  * jointplot 메서드를 사용함 , kind 인잣값을 hex로 지정한다.

# %%
hexbin = sns.jointplot(x='total_bill',y="tip",data=tips, kind='hex')
joint.set_axis_labels(xlabel='Total Bill',ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# <div id='ca8715dc-b695-414c-9a69-aa9ee862b878'></div>
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %% [markdown]
# 4) 이차원 밀집도 그리기
#  * kdeplot 메서드 이용
#  * shade=True : 그래프에 음영 효과를 준다.

# %%
ax = plt.subplots()
ax=sns.kdeplot(data=tips['total_bill'], data2=tips['tip'], shade = True)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <div id='e5030a1a-a55d-4cfe-b806-928afbca9d77'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1681: FutureWarning: Use `x` and `y` rather than `data` `and `data2`
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Tip')

# %% [markdown]
# 5) 바 그래프 그리기
#  * 지정한 변수의 평균을 계산하여 그린다.

# %%
ax = plt.subplots()
ax=sns.barplot(x='time', y='total_bill',data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <div id='7c2491f6-a2b5-4bd0-90ce-da47d037e51b'></div>
# Text(0, 0.5, 'Average total bill')

# %% [markdown]
# 6) 박스 그래프 그리기
#  * 최솟값, 1분위수, 중간값, 3분위수, 최댓값, 이상치 등 다양한 통계량을 한 번에 표현하는 그래프

# %%
ax = plt.subplots()
ax=sns.boxplot(x='time', y='total_bill',data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total bill')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <div id='f9b19d35-b1bd-4118-a4d8-a70338f53b88'></div>
# Text(0, 0.5, 'Total bill')

# %% [markdown]
# 7) 바이올린 그래프
#  * violinplot 메서드 이용
#  * 박스 그래프에 커널 밀도를 추정함.

# %%
ax = plt.subplots()
ax=sns.violinplot(x='time', y='total_bill',data=tips)
ax.set_title('Violin plot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total bill')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <div id='709a2991-cd7f-4bf6-b46f-8854b82ab2a3'></div>
# Text(0, 0.5, 'Total bill')

# %% [markdown]
# 8) 관계 그래프 그리기
#  * pairplot 메서드

# %%
fig = sns.pairplot(tips)

# %% [markdown]
# 9) 관계 그래프의 단점 - 중복된 정보가 표현됨. 대각선을 기준으로 대칭이다.
#  * map_upper 메서드 : 대각선을 기준으로 위쪽에 그릴 그래프를 지정한다.
#
#  map_lower 메서드 : 대각선을 기준으로 아래에 그릴 그래프를 지정한다.

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.distplot, rug=True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1242: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='ac1599ba-94c1-4ec3-ab27-546720780580'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
# ...

# %% [markdown]
#  ### **`<다변량 그래프 그리기>`**
#   앞서 matplotlib라이브러리로 다변량 그래프를 그려보았는데 이번엔 seaborn라이브러리로 다변량 그래프를 그려보자.
#
#   1) seaborn 라이브러리로 바이올린 그래프 그리기 - 색상 추가 옵션 (` hue `)

# %%
ax=plt.subplots()
ax=sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <div id='daaacc59-417b-445d-b6a5-a8e253db166f'></div>

# %% [markdown]
# 2) 산점도, 관계 그래프 그리기 - 색상 추가

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='edc76e37-1d1d-4825-840f-49c9f0dd49a3'></div>

# %%
fig= sns.pairplot(tips, hue='sex')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1242: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='c56ad465-4481-4f51-9e39-1d57f4cbe5a5'></div>

# %% [markdown]
# 3) 산점도 그래프의 크기와 모양 조절하기
#  * scatter_kws={} : 산점도 그래프의 점 크기 조절

# %%
scatter= sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', scatter_kws={'s': tips['size']*10})  #p.108 오류가 나오는 이유:
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-d6b7d998cf39> in <module>
# ----> 1 scatter= sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', scatter_kws={'s': tips['size']*10})  #p.108
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %% [markdown]
# 4) `markers=[]` : 산점도 그래프의 점을 다른 기호로 표현할 수 있음

# %%
scatter=sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',markers=['o','x'],scatter_kws={'s': tips['size']*10})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='7dd6f933-fdd1-4136-ac44-0d59944f361c'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-f69dc7af8fc6> in <module>
# ----> 1 scatter=sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',markers=['o','x'],scatter_kws={'s': tips['size']*10})
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ...

# %% [markdown]
# 5) Implot 메서드로 4개의 데이터 그룹에 대한 그래프 한 번에 그리기

# %%
anscombe_plot = sns.lmplot(x='x',y='y', data=anscombe, fit_reg=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='589f49ca-db73-4db1-a2ff-f17120256239'></div>

# %% [markdown]
# 6) Implot 메서드에서 그룹별로 그래프를 나누어 그리려면
#  * col : 데이터 그룹을 구분할 열 지정
#  * col_warp : 그래프를 그릴 열의 최댓값지정

# %%
ascombe_plot=sns.lmplot(x='x',y='y', data=anscombe, fit_reg=False, col='dataset',col_wrap=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='7f0ad725-480a-44d7-afe1-00cee07ab332'></div>

# %% [markdown]
# [추가로 알아가기!]
# FacetGrid 클래스로 그룹별 그래프 그리기
#
# 1) FacetGrid에 데이터프레임과 그룹을 구분할 열 이름을 전달하여 객체 생성

# %%
facet=sns.FacetGrid(tips,col='time')   
facet.map(sns.distplot, 'total_bill', rug=True) #히스토그램, 밀집도, 양탄자 그래프를 그릴 수 있다.
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='e56beac7-9117-4306-9ee3-d3a6300554fa'></div>
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
# ...

# %% [markdown]
# 2) 다변량 그래프 그려보기

# %%
facet=sns.FacetGrid(tips, col='day', hue='sex')   
facet=facet.map(plt.scatter, 'total_bill','tip')
facet=facet.add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='1cfe301d-223c-4e20-998d-425be41c159f'></div>

# %% [markdown]
# 3) 더 많은 변수를 사용하여 그래프 그리기

# %%
# time, smoker열을 사용하였는데 각 열은 2개의 값을 가지고 있어서 2행 2열의 격자가 만들어진다.
facet=sns.FacetGrid(tips, col='time', row='smoker', hue='sex') 
facet.map(plt.scatter, 'total_bill','tip')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# <div id='d7bd722e-166a-4c46-b8bb-19ed710cc662'></div>

# %% [markdown]
# ## **04-4 데이터프레임과 시리즈로 그래프 그리기**
#
# 1) 히스토그램 그리기

# %%
 ax=plt.subplots()
 ax=tips['total_bill'].plot.hist()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <div id='20b21b6c-2b40-4cf8-b59d-f91165cb78bc'></div>

# %% [markdown]
# 2) 투명도 조절하려면 hist 메서드의 `alpha, bins, ax`인자 사용하면 된다.

# %%
fig, ax=plt.subplots()
ax=tips[['total_bill','tip']].plot.hist(alpha=0.5, bins=20, ax=ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <div id='ba6a2c69-b5b4-4b9b-a6b1-1257e758d105'></div>

# %% [markdown]
# 3) 밀집도 그리기 : kde()
# 산점도 그래프 그리기 : scatter
# 육각 그래프는 : hexbin

# %%
ax=plt.subplots()
ax=tips['tip'].plot.kde()

fig, ax=plt.subplots()
ax=tips.plot.scatter(x='total_bill', y='tip', ax=ax)

fig, ax=plt.subplots()
ax=tips.plot.hexbin(x='total_bill', y='tip', ax=ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <div id='2eeff379-27b5-4399-a3ea-62e24a37b639'></div>

# %% [markdown]
# 4) ` gridsize` : 육각 그래프의 육각형 크기 변경

# %%
fig, ax=plt.subplots()
ax=tips.plot.hexbin(x='total_bill', y='tip', gridsize=10,ax=ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <div id='025d8413-f6a5-45b8-b500-d3d4bc162e70'></div>

# %% [markdown]
# 5) box메서드를 사용하여 그린 박스 그래프

# %%
fig, ax=plt.subplots()
ax=tips.plot.box(ax=ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <div id='676b590a-8010-46a3-8830-655d871a42a6'></div>

# %% [markdown]
# ## **04-5 seaborn 라이브러리로그래프 스타일 설정하기**
#  * set_style 메서드 : 그래프의 스타일 바꾸기
#  * 실행하면 계속 지정 스타일로 바뀐 채로 나옴

# %%
fig, ax=plt.subplots()
ax=sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <div id='e586eb90-242f-4c72-b43b-ef1d936f59ee'></div>

# %% [markdown]
# 2) whitegrid로 스타일을 설정하여 그래프를 그린다. (그래프의 배경에 가로 줄이 생김)

# %%
sns.set_style('whitegrid')
fig, ax=plt.subplots()
ax=sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# <div id='6bf443f1-6140-4b0d-9656-48caf388375a'></div>

# %% [markdown]
# 3) for문을 이용하여 모든 스타일을 하나씩 적용한 그래프

# %%
fig = plt.figure()

seaborn_styles=['darkgrid', 'whitegrid','dark','white','ticks']

for idx, style in enumerate(seaborn_styles):
  plot_position = idx+1
  with sns.axes_style(style):
    ax=fig.add_subplot(2,3,plot_position)
    violin = sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
    violin.set_title(style)

fig.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <div id='8f864109-e60c-4ef8-bb04-3689dc068066'></div>
